# %%
import pandas as pd

# %%
nyc = pd.read_csv('Files/AB_NYC_2019.csv')

# %%
nyc.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
nyc[(nyc['neighbourhood_group'] == 'Manhattan') & (nyc['room_type'] == 'Private room')] \
[['name', 'host_name','neighbourhood_group', 'neighbourhood', 'room_type']]
# Out:
#                                                     name   host_name  \
# 2                    THE VILLAGE OF HARLEM....NEW YORK !   Elisabeth
# 7                       Large Furnished Room Near B'way     Shunichi
# 8                     Cozy Clean Guest Room - Family Apt   MaryEllen
# 11                       Central Manhattan/near Broadway        Kate
# 13      Wonderful Guest Bedroom in Manhattan for SINGLES     Claudio
# ...                                                  ...         ...
# 48876    Cozy, Air-Conditioned Private Bedroom in Harlem      Joseph
# 48883       Sunny Bedroom NYC! Walking to Central Park!!     Kendall
# 48885    Stunning Bedroom NYC! Walking to Central Park!!     Kendall
# 48888  Spacious Room w/ Private Rooftop, Central loca...         Kat
# 48894  Trendy duplex in the very heart of Hell's Kitchen  Christophe
#
#       neighbourhood_group    neighbourhood     room_type
# 2               Manhattan           Harlem  Private room
# ...

# %%
manhattan_lists = nyc['neighbourhood_group'] == 'Manhattan'
private_rooms = nyc['room_type'] == 'Private room'
nyc[manhattan_lists & private_rooms][['name', 'host_name','neighbourhood_group', 'neighbourhood', 'room_type']].sort_values('host_name').head()
# Out:
#                                                     name  \
# 15242        Upper West Side One Bedroom on Central Park
# 3789   Midtown Gem/ Carnegie Hall/theaters/ Central Park
# 35170                Prewar Gem in Middle of Everything!
# 33964                                       2018Serenity
# 38828  Next to train-Spacious-Sleeps 2-Flex Chk In Times
#
#                       host_name neighbourhood_group    neighbourhood  \
# 15242  (Email hidden by Airbnb)           Manhattan  Upper West Side
# 3789   (Email hidden by Airbnb)           Manhattan          Midtown
# 35170  (Email hidden by Airbnb)           Manhattan          Midtown
# 33964              2018Serenity           Manhattan      East Harlem
# 38828                       475           Manhattan           Harlem
#
#           room_type
# 15242  Private room
# 3789   Private room
# 35170  Private room
# 33964  Private room
# 38828  Private room

# %% [markdown]
# ## Lambda

# %%
square = lambda x: x**2

# %%
type(square)
# Out:
# function

# %%
square(234)
# Out:
# 54756

# %%
nyc['name_length'] = nyc['name'].fillna('').apply(len)

# %%
nyc['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
def price_grade(p):
    if p < 80:
        return 'Cheap'
    elif p < 120:
        return 'Medium'
    else:
        return 'Expensive'

# %%
number = 100
price_grade(number)
# Out:
# 'Medium'

# %%
nyc['price'].apply(price_grade)
# Out:
# 0        Expensive
# 1        Expensive
# 2        Expensive
# 3           Medium
# 4           Medium
#            ...
# 48890        Cheap
# 48891        Cheap
# 48892       Medium
# 48893        Cheap
# 48894       Medium
# Name: price, Length: 48895, dtype: object

# %%
nyc['price'].apply(lambda pr: 'Cheap' if pr < 80 else 'Medium' if pr < 120 else 'Expensive')
# Out:
# 0        Expensive
# 1        Expensive
# 2        Expensive
# 3           Medium
# 4           Medium
#            ...
# 48890        Cheap
# 48891        Cheap
# 48892       Medium
# 48893        Cheap
# 48894       Medium
# Name: price, Length: 48895, dtype: object

# %%
nyc['price_group'] = nyc[['room_type', 'price']].apply(lambda row: \
                                                       'Expensive' if row[0] == 'Private room' \
                                                       and row[1] > 120 else 'Other' , axis = 1)

# %%
nyc['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
nyc
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
nyc.select_dtypes(['int', 'float'])
# Out:
#              id   host_id  latitude  longitude  price  minimum_nights  \
# 0          2539      2787  40.64749  -73.97237    149               1
# 1          2595      2845  40.75362  -73.98377    225               1
# 2          3647      4632  40.80902  -73.94190    150               3
# 3          3831      4869  40.68514  -73.95976     89               1
# 4          5022      7192  40.79851  -73.94399     80              10
# ...         ...       ...       ...        ...    ...             ...
# 48890  36484665   8232441  40.67853  -73.94995     70               2
# 48891  36485057   6570630  40.70184  -73.93317     40               4
# 48892  36485431  23492952  40.81475  -73.94867    115              10
# 48893  36485609  30985759  40.75751  -73.99112     55               1
# 48894  36487245  68119814  40.76404  -73.98933     90               7
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
nyc.select_dtypes('int')
# Out:
#              id   host_id  price  minimum_nights  number_of_reviews  \
# 0          2539      2787    149               1                  9
# 1          2595      2845    225               1                 45
# 2          3647      4632    150               3                  0
# 3          3831      4869     89               1                270
# 4          5022      7192     80              10                  9
# ...         ...       ...    ...             ...                ...
# 48890  36484665   8232441     70               2                  0
# 48891  36485057   6570630     40               4                  0
# 48892  36485431  23492952    115              10                  0
# 48893  36485609  30985759     55               1                  0
# 48894  36487245  68119814     90               7                  0
#
#        calculated_host_listings_count  availability_365  name_length
# 0                                   6               365           34
# ...

# %%
nyc['neighbourhood'].nunique()
# Out:
# 221

# %%
nyc['neighbourhood'].mode()
# Out:
# 0    Williamsburg
# Name: neighbourhood, dtype: object

# %%
nyc['price'].mode()
# Out:
# 0    100
# Name: price, dtype: int64

# %%
pd.set_option('max_rows', 300)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 pd.set_option('max_rows', 300)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_config\config.py:256, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     255 def __call__(self, *args, **kwds):
# --> 256     return self.__func__(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_config\config.py:149, in _set_option(*args, **kwargs)
#     146     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     148 for k, v in zip(args[::2], args[1::2]):
# --> 149     key = _get_single_key(k, silent)
#     151     o = _get_registered_option(key)
#     152     if o and o.validator:
#
# ...

# %%
nyc['neighbourhood'].value_counts()
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Fort Wadsworth           1
# Richmondtown             1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: neighbourhood, Length: 221, dtype: int64

# %% [markdown]
# ## Missing Values

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
nyc.loc[nyc['name'].notnull()]
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
nyc[nyc.isna()]
# Out:
#        id name  host_id host_name neighbourhood_group neighbourhood  latitude  \
# 0     NaN  NaN      NaN       NaN                 NaN           NaN       NaN
# 1     NaN  NaN      NaN       NaN                 NaN           NaN       NaN
# 2     NaN  NaN      NaN       NaN                 NaN           NaN       NaN
# 3     NaN  NaN      NaN       NaN                 NaN           NaN       NaN
# 4     NaN  NaN      NaN       NaN                 NaN           NaN       NaN
# ...    ..  ...      ...       ...                 ...           ...       ...
# 48890 NaN  NaN      NaN       NaN                 NaN           NaN       NaN
# 48891 NaN  NaN      NaN       NaN                 NaN           NaN       NaN
# 48892 NaN  NaN      NaN       NaN                 NaN           NaN       NaN
# 48893 NaN  NaN      NaN       NaN                 NaN           NaN       NaN
# 48894 NaN  NaN      NaN       NaN                 NaN           NaN       NaN
#
# ...

# %%
nyc.loc[nyc['name'].isna(), ['name']] = 'Unknown'

# %%
nyc['name'] = nyc['name'].fillna('Unknown')

# %%
nyc.loc[0]['id'] = 555
# Out:
# C:\Users\elad\AppData\Local\Temp\ipykernel_1888\86963504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyc.loc[0]['id'] = 555

# %%
nyc.loc[0, 'id'] = 555

# %%
nyc[nyc['name'].notnull()]
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
nyc = pd.read_csv('Files/AB_NYC_2019.csv')

# %%
nyc.dropna(subset=['id', 'longitude'])
# Out:
#                id                                               name  \
# 0          2539.0                 Clean & quiet apt home by the park
# 1          2595.0                              Skylit Midtown Castle
# 2          3647.0                THE VILLAGE OF HARLEM....NEW YORK !
# 3          3831.0                    Cozy Entire Floor of Brownstone
# 6          5121.0                                    BlissArtsSpace!
# ...           ...                                                ...
# 48890  36484665.0    Charming one bedroom - newly renovated rowhouse
# 48891  36485057.0      Affordable room in Bushwick/East Williamsburg
# 48892  36485431.0            Sunny Studio at Historical Neighborhood
# 48893  36485609.0               43rd St. Time Square-cozy single bed
# 48894  36487245.0  Trendy duplex in the very heart of Hell's Kitchen
#
#         host_id      host_name neighbourhood_group       neighbourhood  \
# ...

# %% [markdown]
# ## Groups

# %%
nyc.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
nyc.groupby('room_type')[['price', 'number_of_reviews', 'minimum_nights']].mean().round(2)
# Out:
#                   price  number_of_reviews  minimum_nights
# room_type
# Entire home/apt  211.80              22.83            8.51
# Private room      89.78              24.11            5.38
# Shared room       70.13              16.60            6.48

# %%
nyc.groupby(['neighbourhood_group', 'room_type'], as_index = False)['price']\
.mean().sort_values('price',ascending = False)
# Out:
#    neighbourhood_group        room_type       price
# 6            Manhattan  Entire home/apt  249.244677
# 3             Brooklyn  Entire home/apt  178.336891
# 12       Staten Island  Entire home/apt  173.846591
# 9               Queens  Entire home/apt  147.050573
# 0                Bronx  Entire home/apt  127.506596
# 7            Manhattan     Private room  116.776622
# 8            Manhattan      Shared room   88.977083
# 4             Brooklyn     Private room   76.500099
# 10              Queens     Private room   71.762456
# 11              Queens      Shared room   69.020202
# 1                Bronx     Private room   66.788344
# 13       Staten Island     Private room   62.292553
# 2                Bronx      Shared room   59.800000
# 14       Staten Island      Shared room   57.444444
# 5             Brooklyn      Shared room   50.527845

# %%
nyc.groupby('neighbourhood_group').size().sort_values(ascending = False)
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# dtype: int64

# %%
nyc.groupby('neighbourhood_group')[['price', 'minimum_nights']].agg(['mean', 'sum'])
# Out:
#                           price            minimum_nights
#                            mean        sum           mean     sum
# neighbourhood_group
# Bronx                 87.496792    95459.0       4.560953    4976
# Brooklyn             124.384967  2500511.0       6.056556  121761
# Manhattan            196.874371  4264102.0       8.579151  185833
# Queens                99.517649   563867.0       5.181433   29358
# Staten Island        114.812332    42825.0       4.831099    1802

# %%
nyc.groupby('neighbourhood_group').agg({'minimum_nights': 'mean', 
                                         'id': 'count',
                                         'price': 'median',
                                         'number_of_reviews': 'sum'})
# Out:
#                      minimum_nights     id  price  number_of_reviews
# neighbourhood_group
# Bronx                      4.560953   1091   65.0            28371.0
# Brooklyn                   6.056556  20104   90.0           486304.0
# Manhattan                  8.579151  21660  150.0           454569.0
# Queens                     5.181433   5666   75.0           156950.0
# Staten Island              4.831099    373   75.0            11541.0

# %%
nyc.groupby('neighbourhood_group').agg(avg_min_nights = ('minimum_nights', 'mean'),
                                      Total_Listings = ('id', 'count'),
                                      median_price = ('price', 'median'))
# Out:
#                      avg_min_nights  Total_Listings  median_price
# neighbourhood_group
# Bronx                      4.560953            1091          65.0
# Brooklyn                   6.056556           20104          90.0
# Manhattan                  8.579151           21660         150.0
# Queens                     5.181433            5666          75.0
# Staten Island              4.831099             373          75.0

# %%
nyc.groupby('neighbourhood_group')['neighbourhood'].nunique()
# Out:
# neighbourhood_group
# Bronx            48
# Brooklyn         47
# Manhattan        32
# Queens           51
# Staten Island    43
# Name: neighbourhood, dtype: int64

# %%
nyc.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889400e+04  4.889500e+04  48895.000000  48894.000000  48892.000000
# mean   1.901753e+07  6.762001e+07     40.728949    -73.952169    152.719545
# std    1.098288e+07  7.861097e+07      0.054530      0.046157    240.161047
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.472371e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967743e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915225e+07  1.074344e+08     40.763115    -73.936273    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48894.000000       38843.000000
# mean         7.029962          23.269420           1.373221
# std         20.510550          44.537062           1.680442
# ...

# %%
wines = pd.read_csv('Files/wines.csv')

# %%
wines.columns
# Out:
# Index(['country', 'designation', 'points', 'price', 'province', 'region_1',
#        'region_2', 'variety', 'winery', 'last_year_points'],
#       dtype='object')

# %%
wines.dropna()
# Out:
#     country                    designation  points  price    province  \
# 0        US              Martha's Vineyard    96.0  235.0  California
# 2        US  Special Selected Late Harvest    96.0   90.0  California
# 3        US                        Reserve    96.0   65.0      Oregon
# 8        US                         Silice    95.0   65.0      Oregon
# 9        US           Gap's Crown Vineyard    95.0   60.0  California
# ..      ...                            ...     ...    ...         ...
# 961      US                  Whole Cluster    90.0   44.0  California
# 965      US                         Estate    90.0   36.0  California
# 968      US     Meredith Mitchell Vineyard    90.0   48.0      Oregon
# 980      US                           Juel    90.0   37.0      Oregon
# 981      US                   Vintage Brut    90.0   28.0      Oregon
#
#                  region_1                 region_2             variety  \
# ...

# %% [markdown]
# ## Ex. 1

# %%
nyc = pd.read_csv('Files/AB_NYC_2019.csv')

# %%
nyc.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
nyc.groupby('host_id').size()
# Out:
# host_id
# 2438         1
# 2571         1
# 2787         6
# 2845         2
# 2868         1
#             ..
# 274273284    1
# 274298453    1
# 274307600    1
# 274311461    1
# 274321313    1
# Length: 37457, dtype: int64

# %%
lists_per_host = nyc['host_id'].value_counts()

# %%
top_hosts = lists_per_host[lists_per_host >= 10].index

# %%
nyc[nyc['host_id'].isin(top_hosts)].groupby('host_id')\
[['neighbourhood_group', 'neighbourhood']].nunique().sort_values('neighbourhood', ascending = False)
# Out:
#            neighbourhood_group  neighbourhood
# host_id
# 107434423                    2             21
# 22541573                     2             14
# 200380610                    1             12
# 2119276                      1             11
# 30283594                     1             10
# ...                        ...            ...
# 154258141                    1              1
# 156505456                    1              1
# 159091490                    1              1
# 159811367                    1              1
# 263053182                    1              1
#
# [115 rows x 2 columns]

# %%
nyc[nyc['calculated_host_listings_count'] >= 10].groupby('host_id')\
[['neighbourhood_group', 'neighbourhood']].nunique()
# Out:
#            neighbourhood_group  neighbourhood
# host_id
# 310670                       1              2
# 344035                       1              1
# 417504                       1              1
# 836168                       1              2
# 1177497                      1              1
# ...                        ...            ...
# 260425153                    1              1
# 260577152                    1              1
# 260618374                    1              2
# 260639745                    1              1
# 263053182                    1              1
#
# [115 rows x 2 columns]

# %%
nyc[nyc['calculated_host_listings_count'] >= 10].groupby('host_id')\
[['neighbourhood_group', 'neighbourhood']].agg('nunique').describe().round(2)
# Out:
#        neighbourhood_group  neighbourhood
# count               115.00         115.00
# mean                  1.16           2.90
# std                   0.49           3.34
# min                   1.00           1.00
# 25%                   1.00           1.00
# 50%                   1.00           1.00
# 75%                   1.00           3.00
# max                   4.00          21.00

# %%
nyc['name'].str.contains('hood')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892     True
# 48893    False
# 48894    False
# Name: name, Length: 48895, dtype: object

# %%
nyc.reset_index()

# %%
number = [1,2,45,78]
45 in number
# Out:
# True

# %%
text.upper()
# Out:
# 'ABC'

# %% [markdown]
# ## pivot

# %%
nyc.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
nyc.pivot_table(index = 'neighbourhood_group')
# Out:
#                      availability_365  calculated_host_listings_count  \
# neighbourhood_group
# Bronx                      165.758937                        2.233731
# Brooklyn                   100.232292                        2.284371
# Manhattan                  111.979410                       12.791330
# Queens                     144.451818                        4.060184
# Staten Island              199.678284                        2.319035
#
#                           host_id            id   latitude  longitude  \
# neighbourhood_group
# Bronx                1.056099e+08  2.273492e+07  40.848305 -73.884552
# Brooklyn             5.671526e+07  1.825685e+07  40.685036 -73.951190
# Manhattan            6.783062e+07  1.877494e+07  40.765062 -73.974607
# Queens               9.615680e+07  2.175500e+07  40.731531 -73.872775
# Staten Island        9.853360e+07  2.159747e+07  40.610225 -74.105805
#
#                      minimum_nights  number_of_reviews       price  \
# ...

# %%
nyc.pivot_table(index = 'neighbourhood_group',
               values = 'number_of_reviews')
# Out:
#                      number_of_reviews
# neighbourhood_group
# Bronx                        26.004583
# Brooklyn                     24.202845
# Manhattan                    20.985596
# Queens                       27.700318
# Staten Island                30.941019

# %%
nyc.pivot_table(index = 'neighbourhood_group',
               values = 'number_of_reviews',
               aggfunc = 'sum')
# Out:
#                      number_of_reviews
# neighbourhood_group
# Bronx                            28371
# Brooklyn                        486574
# Manhattan                       454569
# Queens                          156950
# Staten Island                    11541

# %%
nyc.pivot_table(index = 'neighbourhood_group',
               values = 'number_of_reviews',
               aggfunc = 'sum',
               columns = 'room_type').style.background_gradient()
# Out:
# <style type="text/css">
# #T_709ba_row0_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_709ba_row0_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_709ba_row0_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_709ba_row1_col0, #T_709ba_row1_col1, #T_709ba_row2_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_709ba_row1_col2 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_709ba_row2_col0 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_709ba_row2_col1 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_709ba_row3_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_709ba_row3_col1 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_709ba_row3_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_709ba_row4_col0, #T_709ba_row4_col1, #T_709ba_row4_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_709ba">
# ...

# %%
nyc.groupby(['neighbourhood_group', 'room_type'])['number_of_reviews'].sum().to_frame().style.background_gradient()
# Out:
# <style type="text/css">
# #T_fc983_row0_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_fc983_row1_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_fc983_row2_col0, #T_fc983_row14_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fc983_row3_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fc983_row4_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_fc983_row5_col0, #T_fc983_row12_col0, #T_fc983_row13_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_fc983_row6_col0 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_fc983_row7_col0 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_fc983_row8_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_fc983_row9_col0 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_fc983_row10_col0 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_fc983_row11_col0 {
# ...

# %%
nyc.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
nyc.pivot_table(index = ['neighbourhood_group', 'neighbourhood'],
               aggfunc = 'size',
               columns = ['room_type', 'minimum_nights'],
               fill_value=0)
# Out:
# room_type                         Entire home/apt                              \
# minimum_nights                                1   2   3   4   5   6   7   8
# neighbourhood_group neighbourhood
# Bronx               Allerton                    2  11   1   1   1   0   0   0
#                     Baychester                  0   1   1   1   0   0   0   0
#                     Belmont                     1   2   0   0   0   0   0   0
#                     Bronxdale                   3   1   0   1   0   0   3   0
#                     Castle Hill                 0   2   2   0   0   0   0   0
# ...                                           ...  ..  ..  ..  ..  ..  ..  ..
# Staten Island       Tottenville                 1   1   2   1   0   0   0   0
#                     West Brighton               2   3   0   0   0   0   0   0
#                     Westerleigh                 0   0   1   0   0   0   0   0
#                     Willowbrook                 0   0   0   1   0   0   0   0
# ...

# %%
nyc.pivot_table(index = ['neighbourhood_group', 'room_type'],
                values = 'number_of_reviews',
               aggfunc = 'sum',
                margins = True
               ).head(50)
# Out:
#                                      number_of_reviews
# neighbourhood_group room_type
# Bronx               Entire home/apt              11627
#                     Private room                 16312
#                     Shared room                    432
# Brooklyn            Entire home/apt             267128
#                     Private room                213653
#                     Shared room                   5793
# Manhattan           Entire home/apt             235147
#                     Private room                209150
#                     Shared room                  10272
# Queens              Entire home/apt              60644
#                     Private room                 93561
#                     Shared room                   2745
# Staten Island       Entire home/apt               5857
#                     Private room                  5670
#                     Shared room                     14
# ...

# %%
nyc.set_index(['neighbourhood_group', 'room_type'])
# Out:
#                                            id  \
# neighbourhood_group room_type
# Brooklyn            Private room         2539
# Manhattan           Entire home/apt      2595
#                     Private room         3647
# Brooklyn            Entire home/apt      3831
# Manhattan           Entire home/apt      5022
# ...                                       ...
# Brooklyn            Private room     36484665
#                     Private room     36485057
# Manhattan           Entire home/apt  36485431
#                     Shared room      36485609
#                     Private room     36487245
#
#                                                                                   name  \
# neighbourhood_group room_type
# Brooklyn            Private room                    Clean & quiet apt home by the park
# Manhattan           Entire home/apt                              Skylit Midtown Castle
# ...
