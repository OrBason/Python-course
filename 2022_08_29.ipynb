# %%
import pandas as pd

# %%
orders = pd.read_csv('Files/Global Orders.csv')

# %%
orders[['Sales', 'Profit', 'Quantity']].assign(Big_Order = orders['Quantity'] > 5,
                           Order_size = orders['Quantity'].apply(lambda q: 'Small' if q < 3 else 'Medium' if q < 6 else 'Big'))
# Out:
#           Sales    Profit  Quantity  Big_Order Order_size
# 0      2309.650  762.1845         7       True        Big
# 1      3709.395 -288.7650         9       True        Big
# 2      5175.171  919.9710         9       True        Big
# 3      2892.510  -96.5400         5      False     Medium
# 4      2832.960  311.5200         8       True        Big
# ...         ...       ...       ...        ...        ...
# 51285    65.100    4.5000         5      False     Medium
# 51286     0.444   -1.1100         1      False      Small
# 51287    22.920   11.2308         3      False     Medium
# 51288    13.440    2.4000         2      False      Small
# 51289    61.380    1.8000         3      False     Medium
#
# [51290 rows x 5 columns]

# %%
orders['Order_size'] = orders['Quantity'].apply(lambda q: 'Small' if q < 3 else 'Medium' if q < 6 else 'Big')

# %%
row = ['col1', 'col2', 'col3']
row[row.index('col3')]
# Out:
# 'col3'

# %%
orders
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31/07/2012  31/07/2012        Same Day
# 1       26341    IN-2013-77878  05/02/2013  07/02/2013    Second Class
# 2       25330    IN-2013-71249  17/10/2013  18/10/2013     First Class
# 3       13524  ES-2013-1579342  28/01/2013  30/01/2013     First Class
# 4       47221     SG-2013-4320  05/11/2013  06/11/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19/06/2014  19/06/2014        Same Day
# 51286   35398   US-2014-102288  20/06/2014  24/06/2014  Standard Class
# 51287   40470   US-2013-155768  02/12/2013  02/12/2013        Same Day
# 51288    9596   MX-2012-140767  18/02/2012  22/02/2012  Standard Class
# 51289    6147   MX-2012-134460  22/05/2012  26/05/2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
att = pd.read_csv('Comics/comics_attributes.csv')
att_new = pd.read_csv('Comics/comics_attributes_new.csv')
heroes = pd.read_csv('Comics/comics_heroes.csv')

# %%
heroes
# Out:
#    hero_id          name    Gender Eye color    Race Hair color  Height  \
# 0       29       Ant-Man      Male      blue   Human      Blond     211
# 1       68        Batman      Male      blue   Human      Blond     188
# 2      286      Godzilla  Godzilla    yellow   Kaiju      black     108
# 3      347          Isis    Female      blue   Human      Black     -99
# 4      528   Professor X      Male      blue  Mutant    No Hair     183
# 5      620   Spider-Girl    Female      blue   Human      Brown     170
# 6      722  Wonder Woman    Female      blue  Amazon      Black     183
#
#        Publisher Alignment  Weight
# 0  Marvel Comics      good     122
# 1      DC Comics      good      95
# 2        Classic       bad    2000
# 3      DC Comics      good     -99
# 4  Marvel Comics      good      86
# 5  Marvel Comics      good      54
# 6      DC Comics      good      74

# %%
att
# Out:
#      hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0       Ant-Man    False                False               False
# 1        Batman     True                False               False
# 2      Godzilla     True                False               False
# 3          Isis    False                 True               False
# 4   Professor X    False                False               False
# 5   Spider-Girl     True                 True               False
# 6  Wonder Woman    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True     True
# 2                  False            False        True    False
# 3                  False            False        True    False
# 4                  False            False       False    False
# ...

# %%
att_new
# Out:
#      hero_names  Invisibility
# 0       Ant-Man         False
# 1        Batman         False
# 2      Godzilla         False
# 3          Isis         False
# 4   Professor X         False
# 5   Spider-Girl         False
# 6  Wonder Woman         False

# %%
att.merge(att_new, on='hero_names')
# Out:
#      hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0       Ant-Man    False                False               False
# 1        Batman     True                False               False
# 2      Godzilla     True                False               False
# 3          Isis    False                 True               False
# 4   Professor X    False                False               False
# 5   Spider-Girl     True                 True               False
# 6  Wonder Woman    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True     True
# 2                  False            False        True    False
# 3                  False            False        True    False
# 4                  False            False       False    False
# ...

# %%
heroes[['hero_id','Gender', 'Race', 'name']].merge(att_new, left_on = 'name', right_on = 'hero_names')
# Out:
#    hero_id    Gender    Race          name    hero_names  Invisibility
# 0       29      Male   Human       Ant-Man       Ant-Man         False
# 1       68      Male   Human        Batman        Batman         False
# 2      286  Godzilla   Kaiju      Godzilla      Godzilla         False
# 3      347    Female   Human          Isis          Isis         False
# 4      528      Male  Mutant   Professor X   Professor X         False
# 5      620    Female   Human   Spider-Girl   Spider-Girl         False
# 6      722    Female  Amazon  Wonder Woman  Wonder Woman         False

# %%
heroes
# Out:
#    hero_id          name    Gender Eye color    Race Hair color  Height  \
# 0       29       Ant-Man      Male      blue   Human      Blond     211
# 1       68        Batman      Male      blue   Human      Blond     188
# 2      286      Godzilla  Godzilla    yellow   Kaiju      black     108
# 3      347          Isis    Female      blue   Human      Black     -99
# 4      528   Professor X      Male      blue  Mutant    No Hair     183
# 5      620   Spider-Girl    Female      blue   Human      Brown     170
# 6      722  Wonder Woman    Female      blue  Amazon      Black     183
# 7      320      Superman      Male      blue     NaN      Black     185
#
#        Publisher Alignment  Weight
# 0  Marvel Comics      good   122.0
# 1      DC Comics      good    95.0
# 2        Classic       bad  2000.0
# 3      DC Comics      good   -99.0
# 4  Marvel Comics      good    86.0
# 5  Marvel Comics      good    54.0
# 6      DC Comics      good    74.0
# ...

# %%
heroes.merge(att_new, 
             left_on = 'name', 
             right_on = 'hero_names', 
             how = 'outer', 
             indicator = True).query('_merge != "both"')
# Out:
#    hero_id      name Gender Eye color Race Hair color  Height  Publisher  \
# 7    320.0  Superman   Male      blue  NaN      Black   185.0  DC Comics
# 8      NaN       NaN    NaN       NaN  NaN        NaN     NaN        NaN
#
#   Alignment  Weight  hero_names Invisibility      _merge
# 7      good     NaN         NaN          NaN   left_only
# 8       NaN     NaN  Homelander        False  right_only

# %%
merged_heroes = heroes.merge(att_new, 
             left_on = 'name', 
             right_on = 'hero_names', 
             how = 'outer', 
             indicator = True)
merged_heroes[merged_heroes['_merge'] != 'both']
# Out:
#    hero_id      name Gender Eye color Race Hair color  Height  Publisher  \
# 7    320.0  Superman   Male      blue  NaN      Black   185.0  DC Comics
# 8      NaN       NaN    NaN       NaN  NaN        NaN     NaN        NaN
#
#   Alignment  Weight  hero_names Invisibility      _merge
# 7      good     NaN         NaN          NaN   left_only
# 8       NaN     NaN  Homelander        False  right_only

# %%
data = pd.read_excel('Files/transactions_split.xlsx', sheet_name=None)

# %%
data.keys()
# Out:
# dict_keys(['txs', 'txs_total', 'products', 'customers', 'more_txs'])

# %%
txs = data['txs']
txs_total = data['txs_total']

# %%
txs = txs.merge(txs_total)

# %%
customers = data['customers']

# %%
customers
# Out:
#                  id first_name   last_name                          email  \
# 0   user:2827573233       Addy        Wong  awong0@nationalgeographic.com
# 1   user:7454035285    Baldwin    Banfield            bbanfield1@admin.ch
# 2   user:0318941940     Antons       Eaves              aeaves2@adobe.com
# 3   user:3758864442    Alfreda      Corten         acorten3@pinterest.com
# 4   user:1830161413      Grove   Clayfield      gclayfield4@cafepress.com
# 5   user:6360787324     Galven    Menicomb     gmenicomb5@nydailynews.com
# 6   user:6786367024   Joscelin     Sheasby              jsheasby6@ask.com
# 7   user:6524923692     Rosene      Dailey      rdailey7@miitbeian.gov.cn
# 8   user:9995755008     Granny       Fegan          gfegan8@wikimedia.org
# 9   user:4462566004       Tris      Tocher           ttocher9@blogger.com
# 10  user:8143920399     Abbott        Card                 acarda@nih.gov
# 11  user:6918026665   Eleanore     Kimblen            ekimblenb@fotki.com
# ...

# %%
txs.head(1)
# Out:
#                          transaction_id       date product_id    status  \
# 0  0029e1f5-b648-4787-b13f-563af8dbe7ff 2019-04-16    DA-7365  approved
#
#   payment_method  amount  risk_score  delivery_fee      customer_id platform  \
# 0         PayPal   152.0    0.158209          14.0  user:1448769854      web
#
#    total
# 0  166.0

# %%
cust_totals = txs.groupby('customer_id', as_index = False)\
                                                .agg(Total_orders = ('transaction_id', 'count'),
                                                avg_amnt = ('amount', 'mean'),
                                                first_purchase = ('date', 'min')).round(1)

# %%
customers.merge(cust_totals, right_on = 'customer_id', left_on = 'id')
# Out:
#                  id first_name   last_name                          email  \
# 0   user:7454035285    Baldwin    Banfield            bbanfield1@admin.ch
# 1   user:0318941940     Antons       Eaves              aeaves2@adobe.com
# 2   user:3758864442    Alfreda      Corten         acorten3@pinterest.com
# 3   user:1830161413      Grove   Clayfield      gclayfield4@cafepress.com
# 4   user:6360787324     Galven    Menicomb     gmenicomb5@nydailynews.com
# 5   user:6786367024   Joscelin     Sheasby              jsheasby6@ask.com
# 6   user:6524923692     Rosene      Dailey      rdailey7@miitbeian.gov.cn
# 7   user:9995755008     Granny       Fegan          gfegan8@wikimedia.org
# 8   user:8143920399     Abbott        Card                 acarda@nih.gov
# 9   user:6918026665   Eleanore     Kimblen            ekimblenb@fotki.com
# 10  user:4743601428      Drusy       Blayd                dblaydc@msn.com
# 11  user:7055774601      Lyndy  Chaikovski           lchaikovskid@hhs.gov
# ...

# %% [markdown]
# ## concat

# %%
april_sales = pd.read_csv('Files/Annual_Sales/Sales_April_2019.csv')
dec_sales = pd.read_csv('Files/Annual_Sales/Sales_December_2019.csv')

# %%
april_sales.head(2)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
#
#        Order Date                   Purchase Address
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30  682 Chestnut St, Boston, MA 02215

# %%
dec_sales.head(2)
# Out:
#   Order ID             Product Quantity Ordered Price Each      Order Date  \
# 0   295665  Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666  LG Washing Machine                1      600.0  12/29/19 07:03
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001

# %%
dec_sales.rename(columns = {'Product': 'Product_Name'}, inplace = True)

# %%
labels = ['April', 'December']
# pd.concat([april_sales, dec_sales], ignore_index=True)
pd.concat([april_sales, dec_sales], keys = labels).reset_index()
# Out:
#         level_0  level_1 Order ID                     Product  \
# 0         April        0   176558        USB-C Charging Cable
# 1         April        1   176559  Bose SoundSport Headphones
# 2         April        2   176560                Google Phone
# 3         April        3   176560            Wired Headphones
# 4         April        4   176561            Wired Headphones
# ...         ...      ...      ...                         ...
# 43494  December    25112   319666                         NaN
# 43495  December    25113   319667                         NaN
# 43496  December    25114   319668                         NaN
# 43497  December    25115   319669                         NaN
# 43498  December    25116   319670                         NaN
#
#       Quantity Ordered Price Each      Order Date  \
# 0                    2      11.95  04/19/19 08:46
# 1                    1      99.99  04/07/19 22:30
# 2                    1        600  04/12/19 14:38
# ...

# %%
pd.concat(pd.read_excel('Files/Financial_Report.xlsx', sheet_name=None)).head()
# Out:
#                              Segment                   Country    Product  \
# Financial_Report 0  Channel Partners                   Germany        VTT
#                  1  Channel Partners                    France        VTT
#                  2  Channel Partners  United States of America   Amarilla
#                  3        Government                    Mexico  Carretera
#                  4         Midmarket  United States of America      Paseo
#
#                    Discount Band  Units Sold  Manufacturing Price  Sale Price  \
# Financial_Report 0        Medium      2215.0                  250          12
#                  1        Medium      2234.0                  250          12
#                  2           Low      1989.0                  260          12
#                  3        Medium      1834.0                    3          20
#                  4        Medium      2931.0                   10          15
#
# ...

# %%
pd.concat(pd.read_excel('Files/Financial_Report.xlsx', sheet_name=None)).reset_index(drop= True).head()
# Out:
#             Segment                   Country    Product Discount Band  \
# 0  Channel Partners                   Germany        VTT        Medium
# 1  Channel Partners                    France        VTT        Medium
# 2  Channel Partners  United States of America   Amarilla           Low
# 3        Government                    Mexico  Carretera        Medium
# 4         Midmarket  United States of America      Paseo        Medium
#
#    Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 0      2215.0                  250          12      26580.0    1860.60
# 1      2234.0                  250          12      26808.0    2412.72
# 2      1989.0                  260          12      23868.0     238.68
# 3      1834.0                    3          20      36680.0    2567.60
# 4      2931.0                   10          15      43965.0    3077.55
#
#       Sales     COGS    Profit       Date
# 0  24719.40   6645.0  18074.40 2020-09-01
# ...

# %% [markdown]
# ## Loading a folder

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Python\\Pagaya'

# %%
pwd
# Out:
# 'C:\\Python\\Pagaya'

# %%
path = 'Files/Annual_Sales/'
files = os.listdir(path)
tables = []

for file in files:
    if file.startswith('Sales') and file[-3:] == 'csv':
        df = pd.read_csv(path + file)
        df['Source'] = file.split('_', 1)[1][:-4]
        tables.append(df)
        
tables = pd.concat(tables)

# %%
tables
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1       176559  Bose SoundSport Headphones                1      99.99
# 2       176560                Google Phone                1        600
# 3       176560            Wired Headphones                1      11.99
# 4       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address          Source
# ...

# %%
'Sales_September_2019.csv'.split('_', 1)[1][:-4]
# Out:
# 'September_2019'

# %%
df1 = pd.DataFrame({'col1': [1,2], 'col2': [1,2], 'col3': [1,2]})
df2 = pd.DataFrame({'col2': [11,22], 'col3': [11,22], 'col4': [11,22], 'col5': [11,22]})
pd.concat([df1, df2])
# Out:
#    col1  col2  col3  col4  col5
# 0   1.0     1     1   NaN   NaN
# 1   2.0     2     2   NaN   NaN
# 0   NaN    11    11  11.0  11.0
# 1   NaN    22    22  22.0  22.0

# %%
pd.concat([df1, df2], axis = 1)
# Out:
#    col1  col2  col3  col2  col3  col4  col5
# 0     1     1     1    11    11    11    11
# 1     2     2     2    22    22    22    22

# %%
data.keys()
# Out:
# dict_keys(['txs', 'txs_total', 'products', 'customers', 'more_txs'])

# %%
products = data['products']

# %%
txs
# Out:
#                           transaction_id       date product_id    status  \
# 0   0029e1f5-b648-4787-b13f-563af8dbe7ff 2019-04-16    DA-7365  approved
# 1   002a2614-807c-47e4-b1c4-a1198a38e058 2018-01-27    ZX-9504  declined
# 2   002ae1a3-2aa0-4c54-8cd5-061e2ea126e4 2019-09-28    OP-5356  approved
# 3   002c1879-5910-46e8-b26b-ae1ae101d035 2018-09-12    FG-4238  approved
# 4   002c40de-f032-4e10-b5bd-5ee54918cccc 2019-04-14    SH-6381  approved
# 5   002d0a5c-0c06-4ba7-9e7e-750157854e9b 2019-02-06    RS-5237  approved
# 6   002d71fd-f0e9-4c04-8e25-2eab403231b6 2019-02-12    XX-6114  approved
# 7   002d75df-f207-4218-be5f-e97359c6d7c1 2018-06-17    LT-8444  approved
# 8   002da95c-f9e2-4612-a53b-ee12b68a97bf 2019-05-27    ZQ-9828  declined
# 9   002ebafd-08da-4002-95cd-08e98aa8e61a 2018-09-24    KS-1910  approved
# 10  002fc5fc-5e5f-4fe6-8191-44155586ee64 2018-08-31    KS-1910  approved
# 11  002fe359-4972-4f38-8a5f-559c079f5bac 2019-03-18    YW-3603  approved
# ...

# %%
products[(products['product_category'] == 'Automotive') | (products['product_category'] == 'Kids')]
# Out:
#    product_id product_category
# 6     SH-6381             Kids
# 9     LR-6886       Automotive
# 13    FP-8217       Automotive
# 14    FG-4238             Kids
# 17    DA-7365       Automotive
# 29    BG-0134             Kids

# %%
products.query('product_category == "Automotive" | product_category == "Kids"')
# Out:
#    product_id product_category
# 6     SH-6381             Kids
# 9     LR-6886       Automotive
# 13    FP-8217       Automotive
# 14    FG-4238             Kids
# 17    DA-7365       Automotive
# 29    BG-0134             Kids

# %%
txs['payment_method'].value_counts()
# Out:
# PayPal        19
# Visa          11
# MasterCard     9
# CreditCard     1
# Name: payment_method, dtype: int64

# %%
import seaborn as sns

# %%
sns.set_style('darkgrid')
grid = sns.FacetGrid(txs, col = 'payment_method', row = 'status');
grid.map(sns.histplot, 'amount', color = 'indianred')
grid.map(sns.histplot, 'delivery_fee');

# %%
txs
# Out:
#                           transaction_id       date product_id    status  \
# 0   0029e1f5-b648-4787-b13f-563af8dbe7ff 2019-04-16    DA-7365  approved
# 1   002a2614-807c-47e4-b1c4-a1198a38e058 2018-01-27    ZX-9504  declined
# 2   002ae1a3-2aa0-4c54-8cd5-061e2ea126e4 2019-09-28    OP-5356  approved
# 3   002c1879-5910-46e8-b26b-ae1ae101d035 2018-09-12    FG-4238  approved
# 4   002c40de-f032-4e10-b5bd-5ee54918cccc 2019-04-14    SH-6381  approved
# 5   002d0a5c-0c06-4ba7-9e7e-750157854e9b 2019-02-06    RS-5237  approved
# 6   002d71fd-f0e9-4c04-8e25-2eab403231b6 2019-02-12    XX-6114  approved
# 7   002d75df-f207-4218-be5f-e97359c6d7c1 2018-06-17    LT-8444  approved
# 8   002da95c-f9e2-4612-a53b-ee12b68a97bf 2019-05-27    ZQ-9828  declined
# 9   002ebafd-08da-4002-95cd-08e98aa8e61a 2018-09-24    KS-1910  approved
# 10  002fc5fc-5e5f-4fe6-8191-44155586ee64 2018-08-31    KS-1910  approved
# 11  002fe359-4972-4f38-8a5f-559c079f5bac 2019-03-18    YW-3603  approved
# ...
