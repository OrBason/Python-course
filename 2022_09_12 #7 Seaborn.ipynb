# %% [markdown]
# ## Seaborn

# %% [markdown]
# !pip3 install seaborn

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
pen = sns.load_dataset('penguins')
pen
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
pen['flipper_length_mm'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.set()

# %%
sns.displot(data = pen, 
            x = 'flipper_length_mm',
            height=7, 
            aspect=2, 
            kde = True, 
            bins = 20, 
            hue = 'species',
            col = 'sex',
           row = 'species',
           palette='magma',
           rug = True);

# %%
sns.kdeplot(data = pen, 
            x = 'flipper_length_mm', 
            #fill=True,
           y = 'body_mass_g');

# %%
sns.regplot(data = pen, 
            x = 'flipper_length_mm', 
           y = 'body_mass_g',
           line_kws={'color': 'red'});

# %%
sns.jointplot(data = pen, 
            x = 'flipper_length_mm', 
           y = 'body_mass_g',
             hue = 'sex');

# %%
sns.pairplot(data = pen, palette='magma', kind = 'kde', diag_kind='hist');

# %%
cars = sns.load_dataset('mpg')

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
sns.pairplot(cars, x_vars=['mpg', 'horsepower'], y_vars=['acceleration', 'weight', 'horsepower']);

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 5))
sns.boxplot(data = cars, y = 'weight', x = 'origin');

# %%
plt.figure(figsize = (15, 5))
sns.violinplot(data = cars, y = 'weight', x = 'origin');

# %%
plt.figure(figsize = (15, 5))
sns.swarmplot(data = cars, y = 'weight', x = 'origin');

# %%
pen.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.violinplot(data = pen, x = 'island', y = 'body_mass_g');

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.violinplot(data = tips, x = 'day', y = 'total_bill', palette='magma');

# %%
plt.figure(figsize = (15, 5))
tips.plot.bar(x = 'day', y = 'total_bill', figsize = (15, 5));

# %%
plt.figure(figsize = (15, 5))
sns.barplot(data = tips, x = 'day', y = 'total_bill');

# %%
sns.countplot(tips['day']);
# Out:
# C:\Users\elad\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import pandas as pd

# %% [markdown]
# ## `Category` datatype

# %%
nyc = pd.read_csv('Files/AB_NYC_2019.csv')

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
nyc.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
nyc.select_dtypes('object').nunique()
# Out:
# name                   47905
# host_name              11452
# neighbourhood_group        5
# neighbourhood            221
# room_type                  3
# last_review             1764
# dtype: int64

# %%
nyc[['neighbourhood_group', 'neighbourhood', 'room_type']] = nyc[['neighbourhood_group', 'neighbourhood', 'room_type']].astype('category')

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  category
#  5   neighbourhood                   48895 non-null  category
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  category
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ## Date & Time

# %%
import datetime as dt

# %%
today = (dt.date.today())

# %%
type(dt.datetime.now())
# Out:
# datetime.datetime

# %%
type(today)
# Out:
# datetime.date

# %% [markdown]
# ### to_datetime

# %%
today_ts = pd.to_datetime(today)

# %%
today_ts
# Out:
# Timestamp('2022-09-12 00:00:00')

# %%
type(today_ts)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
today_ts.day_name()
# Out:
# 'Monday'

# %%
today_ts.month_name()
# Out:
# 'September'

# %%
dates = ['2010-01-01', 
         '2012-12-15', 
         '2020-06-09',
        '27-10-2020',
        '27/10/2021',
        '27.12.22',
        '02/28/20',
        '02/11/20',
        '09-january-2020',
        '12-mar-2000',
        'june 9th, 2009',
        '10th of july, 2020']

pd.to_datetime(dates)
# Out:
# C:\Users\elad\AppData\Local\Temp\ipykernel_8072\4221996574.py:14: UserWarning: Parsing '27-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   pd.to_datetime(dates)
# C:\Users\elad\AppData\Local\Temp\ipykernel_8072\4221996574.py:14: UserWarning: Parsing '27/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   pd.to_datetime(dates)
# DatetimeIndex(['2010-01-01', '2012-12-15', '2020-06-09', '2020-10-27',
#                '2021-10-27', '2022-12-27', '2020-02-28', '2020-02-11',
#                '2020-01-09', '2000-03-12', '2009-06-09', '2020-07-10'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates = ['10/12/2020', '06/02/2021', '03/05/2022']

pd.to_datetime(dates, format = '%d/%m/%Y')
# Out:
# DatetimeIndex(['2020-12-10', '2021-02-06', '2022-05-03'], dtype='datetime64[ns]', freq=None)

# %%
dates = ['2010-01-01', 
         '2012-12-15', 
         '2020-06-09',
        '27-10-2020',
        '27/10/2021',
        '27.12.22',
        '02/28/20',
         'hello',
        '02/11/20',
        '09-january-2020',
        '12-mar-2000',
        'june 9th, 2009',
        '10th of july, 2020']

pd.to_datetime(dates, errors='coerce')
# Out:
# C:\Users\elad\AppData\Local\Temp\ipykernel_8072\3001869804.py:15: UserWarning: Parsing '27-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   pd.to_datetime(dates, errors='coerce')
# C:\Users\elad\AppData\Local\Temp\ipykernel_8072\3001869804.py:15: UserWarning: Parsing '27/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   pd.to_datetime(dates, errors='coerce')
# DatetimeIndex(['2010-01-01', '2012-12-15', '2020-06-09', '2020-10-27',
#                '2021-10-27', '2022-12-27', '2020-02-28',        'NaT',
#                '2020-02-11', '2020-01-09', '2000-03-12', '2009-06-09',
#                '2020-07-10'],
#               dtype='datetime64[ns]', freq=None)

# %%
nyc = pd.read_csv('Files/AB_NYC_2019.csv', parse_dates=['last_review'])
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
nyc['last_review'] = nyc['last_review'].astype('datetime64')
nyc['last_review'] = pd.to_datetime(nyc['last_review'])

# %%
rev_col = nyc['last_review']

# %%
nyc['last_review']
# Out:
# 0       2018-10-19
# 1       2019-05-21
# 2              NaT
# 3       2019-07-05
# 4       2018-11-19
#            ...
# 48890          NaT
# 48891          NaT
# 48892          NaT
# 48893          NaT
# 48894          NaT
# Name: last_review, Length: 48895, dtype: datetime64[ns]

# %%
rev_col.dt.strftime('%m==>%Y')
# Out:
# 0        10==>2018, 18
# 1        05==>2019, 19
# 2                  NaN
# 3        07==>2019, 19
# 4        11==>2018, 18
#              ...
# 48890              NaN
# 48891              NaN
# 48892              NaN
# 48893              NaN
# 48894              NaN
# Name: last_review, Length: 48895, dtype: object

# %%
now = pd.to_datetime(dt.datetime.now())

# %%
now.round('d')
# Out:
# Timestamp('2022-09-13 00:00:00')

# %% [markdown]
# ### Date_Range

# %%
list(range(1,58,4))
# Out:
# [1, 5, 9, 13, 17, 21, 25, 29, 33, 37, 41, 45, 49, 53, 57]

# %%
today
# Out:
# datetime.date(2022, 9, 12)

# %%
pd.date_range(start=today, end = '2022-12-31', freq='3W')
# Out:
# DatetimeIndex(['2022-09-18', '2022-10-09', '2022-10-30', '2022-11-20',
#                '2022-12-11'],
#               dtype='datetime64[ns]', freq='3W-SUN')

# %%
pd.date_range(start=today, end = '2022-12-31', freq='W-SUN')
# Out:
# DatetimeIndex(['2022-09-18', '2022-09-25', '2022-10-02', '2022-10-09',
#                '2022-10-16', '2022-10-23', '2022-10-30', '2022-11-06',
#                '2022-11-13', '2022-11-20', '2022-11-27', '2022-12-04',
#                '2022-12-11', '2022-12-18', '2022-12-25'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start=today, end = '2022-12-31', freq='W-SUN')

# %%
pd.date_range(end = '2022-12-31', freq='W-SUN', periods=200)
# Out:
# DatetimeIndex(['2019-03-03', '2019-03-10', '2019-03-17', '2019-03-24',
#                '2019-03-31', '2019-04-07', '2019-04-14', '2019-04-21',
#                '2019-04-28', '2019-05-05',
#                ...
#                '2022-10-23', '2022-10-30', '2022-11-06', '2022-11-13',
#                '2022-11-20', '2022-11-27', '2022-12-04', '2022-12-11',
#                '2022-12-18', '2022-12-25'],
#               dtype='datetime64[ns]', length=200, freq='W-SUN')

# %%
now
# Out:
# Timestamp('2022-09-12 12:26:25.513110')

# %%
pd.date_range(start = now, end = '2022-09-13', periods=100)
# Out:
# DatetimeIndex([   '2022-09-12 12:26:25.513110',
#                '2022-09-12 12:33:25.861462424',
#                '2022-09-12 12:40:26.209814848',
#                '2022-09-12 12:47:26.558167272',
#                '2022-09-12 12:54:26.906519696',
#                '2022-09-12 13:01:27.254872121',
#                '2022-09-12 13:08:27.603224545',
#                '2022-09-12 13:15:27.951576969',
#                '2022-09-12 13:22:28.299929393',
#                '2022-09-12 13:29:28.648281818',
#                '2022-09-12 13:36:28.996634242',
#                '2022-09-12 13:43:29.344986666',
#                '2022-09-12 13:50:29.693339090',
#                '2022-09-12 13:57:30.041691515',
#                '2022-09-12 14:04:30.390043939',
#                '2022-09-12 14:11:30.738396363',
#                '2022-09-12 14:18:31.086748787',
#                '2022-09-12 14:25:31.435101212',
#                '2022-09-12 14:32:31.783453636',
#                '2022-09-12 14:39:32.131806060',
# ...

# %% [markdown]
# ### DateOffset

# %%
five_days = pd.DateOffset(months = 5, days = 4, minutes = 18)

print((today + five_days))
# Out:
# 2023-02-16 00:18:00

# %%
year_os = pd.DateOffset(years = 1)

pd.date_range(start = today, freq = year_os, periods = 20)
# Out:
# DatetimeIndex(['2022-09-12', '2023-09-12', '2024-09-12', '2025-09-12',
#                '2026-09-12', '2027-09-12', '2028-09-12', '2029-09-12',
#                '2030-09-12', '2031-09-12', '2032-09-12', '2033-09-12',
#                '2034-09-12', '2035-09-12', '2036-09-12', '2037-09-12',
#                '2038-09-12', '2039-09-12', '2040-09-12', '2041-09-12'],
#               dtype='datetime64[ns]', freq='<DateOffset: years=1>')

# %%
today = pd.Timestamp('2022-09-12')
tomorrow = pd.Timestamp('2023-09-13 12:34:13')

# %%
tomorrow - today
# Out:
# Timedelta('366 days 12:34:13')

# %%
nyc['last_review'] - nyc['last_review']
# Out:
# 0       0 days
# 1       0 days
# 2          NaT
# 3       0 days
# 4       0 days
#          ...
# 48890      NaT
# 48891      NaT
# 48892      NaT
# 48893      NaT
# 48894      NaT
# Name: last_review, Length: 48895, dtype: timedelta64[ns]

# %% [markdown]
# ### Datetime index

# %%
nyc = pd.read_csv('Files/AB_NYC_2019.csv')
nyc = nyc.dropna(subset = ['last_review'])
nyc.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
nyc.set_index('last_review', inplace = True)
nyc
# Out:
#                    id                                              name  \
# last_review
# 2018-10-19       2539                Clean & quiet apt home by the park
# 2019-05-21       2595                             Skylit Midtown Castle
# 2019-07-05       3831                   Cozy Entire Floor of Brownstone
# 2018-11-19       5022  Entire Apt: Spacious Studio/Loft by central park
# 2019-06-22       5099         Large Cozy 1 BR Apartment In Midtown East
# ...               ...                                               ...
# 2019-07-07   36425863        Lovely Privet Bedroom with Privet Restroom
# 2019-07-07   36427429                          No.2 with queen size bed
# 2019-07-07   36438336                                   Seas The Moment
# 2019-07-07   36442252                     1B-1B apartment near by Metro
# 2019-07-08   36455809           Cozy Private Room in Bushwick, Brooklyn
#
#                host_id    host_name neighbourhood_group    neighbourhood  \
# last_review
# ...

# %%
nyc.loc['2018-10-19': '2018-12-31'] # error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [207], in <cell line: 1>()
# ----> 1 nyc.loc['2018-10-19': '2018-12-31']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1180, in _LocIndexer._getitem_axis(self, key, axis)
#    1178 if isinstance(key, slice):
#    1179     self._validate_key(key, axis)
# -> 1180     return self._get_slice_axis(key, axis=axis)
#    1181 elif com.is_bool_indexer(key):
#    1182     return self._getbool_axis(key, axis=axis)
#
# ...

# %%
nyc.reset_index(inplace = True)

# %%
nyc['last_review'] = pd.to_datetime(nyc['last_review'])

# %%
nyc.set_index('last_review', inplace = True)

# %%
nyc.loc['2018-10-19': '2018-12-31']
# Out:
#                    id                                               name  \
# last_review
# 2018-10-19       2539                 Clean & quiet apt home by the park
# 2018-11-19       5022   Entire Apt: Spacious Studio/Loft by central park
# 2018-10-31       6090                      West Village Nest - Superhost
# 2018-11-03      15396                 Sunny & Spacious Chelsea Apartment
# 2018-10-28      22911                The Stuydio Modern and Light Filled
# ...               ...                                                ...
# 2018-12-30   31057368     2 bedroom apt in the heart of Bushwick (House)
# 2018-12-31   31057394  Cozy bedroom in spacious Crown Heights apartment!
# 2018-12-30   31058735             25 minutes from Manhattan, shared room
# 2018-12-31   31145652        Great Manhattan Apartment, Near ALL! Quiet!
# 2018-12-31   31149465  Spacious Duplex with two terraces and a roof deck
#
#                host_id host_name neighbourhood_group       neighbourhood  \
# ...

# %%
nyc.loc['2019-03']
# Out:
#                    id                                              name  \
# last_review
# 2019-03-25      14322               Beautiful Apartment in Manhattan!!!
# 2019-03-30      15711        2 bedroom - Upper East Side-great for kids
# 2019-03-23      19159              Spacious luminous apt Upper West NYC
# 2019-03-31      36703                 Sunny, clean 1 bdrm in W. Village
# 2019-03-31      79782  Williamsburg HUGE, PRIVATE BATH - Next to Train!
# ...               ...                                               ...
# 2019-03-30   33197108                                      Welcome home
# 2019-03-22   33214322             large & spacious bedroom-Williamsburg
# 2019-03-23   33227584                              King Size Dream Room
# 2019-03-29   33367026        Artist apartment in the heart of Brooklyn!
# 2019-03-30   33433134                             Luxury 1 Bedroom Loft
#
#                host_id  host_name neighbourhood_group       neighbourhood  \
# last_review
# ...

# %%
nyc.loc['2019']['number_of_reviews'].sum()
# Out:
# 1013755

# %%
nyc.reset_index(inplace= True)

# %%
nyc[nyc['last_review'].dt.year == 2019]
# Out:
#       last_review        id                                        name  \
# 1      2019-05-21      2595                       Skylit Midtown Castle
# 2      2019-07-05      3831             Cozy Entire Floor of Brownstone
# 4      2019-06-22      5099   Large Cozy 1 BR Apartment In Midtown East
# 6      2019-06-24      5178            Large Furnished Room Near B'way
# 8      2019-06-09      5238          Cute & Cozy Lower East Side 1 bdrm
# ...           ...       ...                                         ...
# 38838  2019-07-07  36425863  Lovely Privet Bedroom with Privet Restroom
# 38839  2019-07-07  36427429                    No.2 with queen size bed
# 38840  2019-07-07  36438336                             Seas The Moment
# 38841  2019-07-07  36442252               1B-1B apartment near by Metro
# 38842  2019-07-08  36455809     Cozy Private Room in Bushwick, Brooklyn
#
#          host_id    host_name neighbourhood_group    neighbourhood  latitude  \
# ...

# %%
nyc.query('last_review.dt.year == 2019 & neighbourhood_group == "Manhattan"')
# Out:
#       last_review        id                                              name  \
# 1      2019-05-21      2595                             Skylit Midtown Castle
# 4      2019-06-22      5099         Large Cozy 1 BR Apartment In Midtown East
# 6      2019-06-24      5178                  Large Furnished Room Near B'way
# 8      2019-06-09      5238                Cute & Cozy Lower East Side 1 bdrm
# 9      2019-06-22      5295                  Beautiful 1br on Upper West Side
# ...           ...       ...                                               ...
# 38830  2019-07-06  36318560   Luxury Sun-filled Private Room near Time Square
# 38831  2019-07-03  36335990               Sunny Studio steps from Wall Street
# 38833  2019-07-05  36351128  One bedroom without roomies, close to everything
# 38836  2019-07-06  36411407              Brand new 1 bedroom steps from Soho!
# 38838  2019-07-07  36425863        Lovely Privet Bedroom with Privet Restroom
#
# ...

# %%
nyc = pd.read_csv('Files/AB_NYC_2019.csv')

plt.figure(figsize = (15, 4))
sns.lineplot(data = nyc, x = 'last_review', y = 'number_of_reviews');
# Out:
# <AxesSubplot:xlabel='last_review', ylabel='number_of_reviews'>

# %%
nyc = pd.read_csv('Files/AB_NYC_2019.csv')
nyc.sort_values('last_review', inplace = True)

plt.figure(figsize = (15, 4))
sns.lineplot(data = nyc, x = 'last_review', y = 'number_of_reviews');

# %%
nyc = pd.read_csv('Files/AB_NYC_2019.csv')
nyc['last_review'] = pd.to_datetime(nyc['last_review'])

plt.figure(figsize = (15, 4))
sns.lineplot(data = nyc, x = 'last_review', y = 'number_of_reviews');

# %%
nyc['year'] = nyc['last_review'].dt.year
nyc['month'] = nyc['last_review'].dt.month_name()
nyc['week'] = nyc['last_review'].dt.week
# Out:
# C:\Users\elad\AppData\Local\Temp\ipykernel_8072\2765824423.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   nyc['week'] = nyc['last_review'].dt.week

# %%
rev_by_month = nyc.groupby(['year', 'month'], as_index = False)['number_of_reviews'].sum()

# %%
rev_by_month
# Out:
#       year      month  number_of_reviews
# 0   2011.0      April                 14
# 1   2011.0   December                 34
# 2   2011.0      March                  1
# 3   2011.0        May                  2
# 4   2011.0  September                 10
# ..     ...        ...                ...
# 87  2019.0    January              20750
# 88  2019.0       July             243262
# 89  2019.0       June             619907
# 90  2019.0      March              11307
# 91  2019.0        May              86486
#
# [92 rows x 3 columns]

# %%
plt.figure(figsize = (15, 4))
sns.lineplot(data = rev_by_month, x = 'year', y = 'number_of_reviews', markers = True);

# %%
rev_by_month.plot(x = 'year', y = 'number_of_reviews');

# %% [markdown]
# ## Resample

# %%
orders = pd.read_csv('Files/Global Orders.csv')
orders.set_index('Order Date').plot(y = 'Profit', figsize = (15,4));

# %%
orders = pd.read_csv('Files/Global Orders.csv')
orders.set_index('Order Date').sort_index().plot(y = 'Profit', figsize = (15,4));

# %%
orders = pd.read_csv('Files/Global Orders.csv')
orders['Order Date'] = pd.to_datetime(orders['Order Date'], format = '%d/%m/%Y')
orders.set_index('Order Date').sort_index().plot(y = 'Profit', figsize = (15,4));

# %%
orders.groupby(orders['Order Date'].dt.year)['Profit'].sum().plot()
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
orders.set_index('Order Date', inplace = True)

# %%
orders.sort_index(inplace = True)

# %%
orders.resample('W')[['Profit', 'Sales', 'Shipping Cost']].sum()
# Out:
#                  Profit         Sales  Shipping Cost
# Order Date
# 2011-01-02    201.99300    1122.78300          88.77
# 2011-01-09   2752.07684   25827.28344        2534.90
# 2011-01-16   2862.55758   27169.67248        3543.94
# 2011-01-23   3536.63394   21799.13634        2387.35
# 2011-01-30  -2220.80560   15337.02860        1552.90
# ...                 ...           ...            ...
# 2014-12-07  12283.64692  111222.48302       12394.61
# 2014-12-14   6266.90584  113998.93574       11783.00
# 2014-12-21   9274.91100   99450.13210       11705.62
# 2014-12-28  13470.67474  123273.28474       12846.10
# 2015-01-04   5620.38218   55198.85788        6124.77
#
# [210 rows x 3 columns]

# %%
orders['Profit'].resample('D').sum().plot(figsize = (15,4));
orders['Profit'].resample('W').sum().plot(figsize = (15,4));
orders['Profit'].resample('M').sum().plot(figsize = (15,4));

# %% [markdown]
# ## Rolling

# %%
orders['Profit']
# Out:
# Order Date
# 2011-01-01      29.6400
# 2011-01-01      36.0360
# 2011-01-01     106.1400
# 2011-01-01      15.3420
# 2011-01-01     -26.0550
#                 ...
# 2014-12-31      12.3600
# 2014-12-31   -1195.2387
# 2014-12-31       4.0530
# 2014-12-31       6.4000
# 2014-12-31     -25.2780
# Name: Profit, Length: 51290, dtype: float64

# %%
orders['Profit'].resample('D').sum().plot(figsize = (15,4));

# %%
daily = orders['Profit'].resample('D').sum()

# %%
daily.head()
# Out:
# Order Date
# 2011-01-01     198.87300
# 2011-01-02       3.12000
# 2011-01-03     184.59720
# 2011-01-04     635.12344
# 2011-01-05    1053.36990
# Freq: D, Name: Profit, dtype: float64

# %%
daily.rolling(10).mean().plot(figsize = (15,4));
