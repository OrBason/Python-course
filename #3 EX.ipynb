# %%
import pandas as pd

# %%
import os

# %%
os.chdir('/Users/or.bason/Desktop/Python_course') #define the path without the file and after only the file #2

# %%
losttb = pd.read_csv('lost-found-adoptable-pets.csv') #read the file (without the path - it was defined before by chdir

# %%
losttb.columns
# Out:
# Index(['impound_no', 'Animal_ID', 'Data_Source', 'Record_Type', 'Link',
#        'Current_Location', 'Animal_Name', 'animal_type', 'Age',
#        'Animal_Gender', 'Animal_Breed', 'Animal_Color', 'Date', 'Date_Type',
#        'Obfuscated_Address', 'City', 'State', 'Zip', 'jurisdiction',
#        'obfuscated_latitude', 'obfuscated_longitude', 'Image',
#        'image_alt_text', 'location_for_map', 'Memo'],
#       dtype='object')

# %%
losttb.shape
# Out:
# (409, 25)

# %%
losttb.tail(3)
# Out:
#      impound_no Animal_ID                              Data_Source  \
# 406  K17-104272   A544172  Regional Animal Services of King County
# 407  K17-103886   A542550  Regional Animal Services of King County
# 408  K17-103445   A540621  Regional Animal Services of King County
#
#     Record_Type                                               Link  \
# 406        LOST  http://petharbor.com/PublicDetail.asp?searchty...
# 407        LOST  http://petharbor.com/PublicDetail.asp?searchty...
# 408        LOST  http://petharbor.com/PublicDetail.asp?searchty...
#
#     Current_Location Animal_Name animal_type  Age Animal_Gender  ...    City  \
# 406             LOST       Sadie         Dog  NaN        Female  ...     NaN
# 407             LOST      Maddie         Dog  NaN        Female  ...  SEATAC
# 408             LOST       Chloe         Cat  NaN        Female  ...     NaN
#
#     State      Zip  jurisdiction obfuscated_latitude obfuscated_longitude  \
# ...

# %%
losttb.loc[20:27] between rows 20-37
# Out:
#     impound_no Animal_ID                              Data_Source Record_Type  \
# 20  K17-103887   A542553  Regional Animal Services of King County       FOUND
# 21  K17-104154   A543669  Regional Animal Services of King County        LOST
# 22  K17-103714   A541805  Regional Animal Services of King County        LOST
# 23  K17-103677   A541534  Regional Animal Services of King County        LOST
# 24  K17-104479   A545107  Regional Animal Services of King County        LOST
# 25  K17-104055   A543249  Regional Animal Services of King County        LOST
# 26  K17-104450   A544874  Regional Animal Services of King County        LOST
# 27  K17-103877   A542542  Regional Animal Services of King County        LOST
#
#                                                  Link Current_Location  \
# 20  http://petharbor.com/PublicDetail.asp?searchty...   In Public Home
# 21  http://petharbor.com/PublicDetail.asp?searchty...             LOST
# ...

# %%
losttb['animal_type'].value_counts()
# Out:
# Cat           287
# Dog           102
# Dead Cat        8
# Goat/sheep      2
# Rabbit Sh       2
# Dead Dog        2
# Hamster         2
# Bird            1
# Angora          1
# Dead Bird       1
# Lop-Mini        1
# Name: animal_type, dtype: int64

# %%
losttb.loc[0:2,'Animal_Name':'Animal_Color']
# Out:
#   Animal_Name animal_type  Age Animal_Gender          Animal_Breed  \
# 0         NaN         Cat  NaN           NaN     Domestic Longhair
# 1        Neko         Cat  NaN          Male    Domestic Shorthair
# 2      Trixie         Dog  NaN        Female  Jack Russell Terrier
#
#       Animal_Color
# 0  White / Unknown
# 1          Unknown
# 2          Unknown

# %%
losttb.loc[0:2,['Animal_Name','Animal_Color']]
# Out:
#   Animal_Name     Animal_Color
# 0         NaN  White / Unknown
# 1        Neko          Unknown
# 2      Trixie          Unknown

# %%
losttb.iloc[:,[0,2,4]]
# Out:
#      impound_no                              Data_Source  \
# 0    K17-103806  Regional Animal Services of King County
# 1    K17-103558  Regional Animal Services of King County
# 2    K17-104020  Regional Animal Services of King County
# 3    K17-103994  Regional Animal Services of King County
# 4    K17-104418  Regional Animal Services of King County
# ..          ...                                      ...
# 404  K17-103413  Regional Animal Services of King County
# 405  K17-104617  Regional Animal Services of King County
# 406  K17-104272  Regional Animal Services of King County
# 407  K17-103886  Regional Animal Services of King County
# 408  K17-103445  Regional Animal Services of King County
#
#                                                   Link
# 0    http://petharbor.com/PublicDetail.asp?searchty...
# 1    http://petharbor.com/PublicDetail.asp?searchty...
# 2    http://petharbor.com/PublicDetail.asp?searchty...
# 3    http://petharbor.com/PublicDetail.asp?searchty...
# ...

# %%
losttb['animal_type'].value_counts()
# Out:
# Cat           287
# Dog           102
# Dead Cat        8
# Goat/sheep      2
# Rabbit Sh       2
# Dead Dog        2
# Hamster         2
# Bird            1
# Angora          1
# Dead Bird       1
# Lop-Mini        1
# Name: animal_type, dtype: int64

# %%
losttb.loc[[86, 142, 251, 307],['Record_Type','Animal_Name','Current_Location','City']]
# Out:
#     Record_Type Animal_Name  \
# 86        FOUND        Onyx
# 142       FOUND       Mcgee
# 251       FOUND       Cider
# 307       FOUND       Cocoa
#
#                                       Current_Location       City
# 86   King County Pet Adoption Center 21615 64TH AVE...    TUKWILA
# 142                                               Neko       KENT
# 251  King County Pet Adoption Center 21615 64TH AVE...       KENT
# 307  King County Pet Adoption Center 21615 64TH AVE...  COVINGTON
