# %% [markdown]
# # IMPORT AND DEFINITION

# %%
import pandas as pd #Every time as a start

# %%
pwd #where python is looking
# Out:
# '/Users/or.bason'

# %%
open('/Users/or.bason/Desktop/Python_course/sample_transactions.csv').read()  #read the file (by payh)  #1

# %%
import os

# %%
os.chdir('/Users/or.bason/Desktop/Python_course') #define the path without the file and after only the file #2

# %%
open('sample_transactions.csv').read()  #read the file (without the path - it was defined before by chdir
# Out:
# 'transaction_id,date,product_id,status,payment_method,amount,discount,number_of_items,risk_score,delivery_fee,customer_id,platform\n0029e1f5-b648-4787-b13f-563af8dbe7ff,2019-04-16,b3xjvqj,approved,PayPal,152,0.017005261546893163,6,0.1582092864276342,14,02cf65ec-1ef0-40a6-b44f-36e4c8b644b4,web\n002a2614-807c-47e4-b1c4-a1198a38e058,2018-01-27,3tkc284,declined,Visa,43,0.017763185774012376,1,0.730812803683491,10,02dd9254-23b6-4b32-b53a-17fdfdd8538e,web\n002ae1a3-2aa0-4c54-8cd5-061e2ea126e4,2019-09-28,d7fhbn2,approved,MasterCard,600,0.04194369284943143,3,0.4776380484991445,3,02df87d6-d1cd-494d-a823-97119ec9fece,mobile\n002c1879-5910-46e8-b26b-ae1ae101d035,2018-09-12,YZCTBC4JWQNE627OCIAQRPABAM,approved,Visa,325,0.009637433850003197,7,0.6942332773169644,2,02e09992-334b-468f-8be8-924831e7164c,web\n002c40de-f032-4e10-b5bd-5ee54918cccc,2019-04-14,jj6dcfdg,approved,PayPal,17,0.019171803449324558,6,0.03975967109645584,1,02eb0fde-b132-447e-9493-6a0d66aacc55,web\n002d0a5c-0c06-4ba7-9e7e-750157854e
# ...

# %% [markdown]
# # Create Table and Read

# %%
tran=pd.read_csv('sample_transactions.csv')    #create and read the table

# %%
 tran.columns   #get the fields names into the table   -- #objects is a text(string)
# Out:
# Index(['transaction_id', 'date', 'product_id', 'status', 'payment_method',
#        'amount', 'discount', 'number_of_items', 'risk_score', 'delivery_fee',
#        'customer_id', 'platform'],
#       dtype='object')

# %%
tran.info()  #info of the fields into table  -- Name/type/howmany nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   transaction_id   41 non-null     object
#  1   date             41 non-null     object
#  2   product_id       40 non-null     object
#  3   status           41 non-null     object
#  4   payment_method   41 non-null     object
#  5   amount           41 non-null     int64
#  6   discount         41 non-null     float64
#  7   number_of_items  41 non-null     int64
#  8   risk_score       41 non-null     float64
#  9   delivery_fee     41 non-null     int64
#  10  customer_id      41 non-null     object
#  11  platform         41 non-null     object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.0+ KB

# %%
tran.shape   #what is the shape of the table - 41 on 12
# Out:
# (41, 12)

# %%
tran.size   #how many values- total
# Out:
# 492

# %% [markdown]
# # Get values from Table

# %%
tran['product_id']        #get a values from table - tran withput nothing is all the fields in table  #one field
# Out:
# 0                        b3xjvqj
# 1                        3tkc284
# 2                        d7fhbn2
# 3     YZCTBC4JWQNE627OCIAQRPABAM
# 4                       jj6dcfdg
# 5                       hteg9fnr
# 6                        b76yq78
# 7     WJ7DHOEK4WMLFW7OXIJRGYABRY
# 8     7BNHPLRSJPBWTGTLMDJWA6HQXA
# 9                        d72d9gd
# 10    VECOP7OEMFZEZJS3NX5FLTXLM4
# 11                      mzdqay78
# 12    6VOA6SDH5LR27HCFRGU4P7T3DQ
# 13                       7k34qfw
# 14    NX4FRCEJB6HBCVQ6LYQLPQ5KWQ
# 15    AEFYC5YOLGTB4IEOAPX3YTFX4E
# 16    W2JHII6424FHXZYIIESZ2GGXBY
# 17                      8qz31w6b
# 18                       jm9dzm6
# 19                       n474brp
# 20                      9gz7qasn
# 21    AARBJEOLFMKYL4SA2WJ2DS2VS4
# 22                       8z6ph32
# 23    U5DC7KQPEZTFCYNITQMGRFKFQU
# 24    MMFZIWL7DZBUCYCYVKRLL6JIA4
# 25                       dsbjrdd
# 26                       7r95cmd
# 27                      bgaqgc8f
# ...

# %%
cols=tran['product_id','transaction_id','status']    #more than 1 fields   #twice[]
tran[cols]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %% [markdown]
# # Function

# %%
tran.head(2) #first 2 rows
# Out:
#                          transaction_id        date product_id    status  \
# 0  0029e1f5-b648-4787-b13f-563af8dbe7ff  2019-04-16    b3xjvqj  approved
# 1  002a2614-807c-47e4-b1c4-a1198a38e058  2018-01-27    3tkc284  declined
#
#   payment_method  amount  discount  number_of_items  risk_score  delivery_fee  \
# 0         PayPal     152  0.017005                6    0.158209            14
# 1           Visa      43  0.017763                1    0.730813            10
#
#                             customer_id platform
# 0  02cf65ec-1ef0-40a6-b44f-36e4c8b644b4      web
# 1  02dd9254-23b6-4b32-b53a-17fdfdd8538e      web

# %%
tran.tail(2) #last 2 rows
# Out:
#                           transaction_id        date product_id    status  \
# 39  0307b5fd-7238-4ba6-8402-d41aba331ddf  2019-01-18   ckray5xd  approved
# 40  02f7d55a-957a-43dd-90bf-78f7220a2d86  2018-08-28    mgb3m44  declined
#
#    payment_method  amount  discount  number_of_items  risk_score  \
# 39     MasterCard     604  0.044472                7    0.968397
# 40     MasterCard     100  0.047521                6    0.603461
#
#     delivery_fee                           customer_id platform
# 39             0  05b8916d-b217-4caf-afe1-48e64015c1e5      web
# 40            18  05bb8b02-28a8-471a-ae19-2c8eb55dac53   mobile

# %%
tran.sample(2) #middle (center) 2 rows
# Out:
#                           transaction_id        date product_id    status  \
# 34  02fdcd8f-e1a9-43d9-b7c2-142c78fc7e90  2019-02-02        NaN  approved
# 20  0115d59c-c025-4ff4-a0ee-fd2704becff4  2018-04-23   9gz7qasn  approved
#
#    payment_method  amount  discount  number_of_items  risk_score  \
# 34           Visa     413  0.003353                5    0.722797
# 20         PayPal     119  0.015983                1    0.342077
#
#     delivery_fee                           customer_id platform
# 34            15  0502f9e6-4609-4e84-8378-c649203e5622      web
# 20             6  030fea3e-5eff-4714-af98-28e42bf8e86d      web

# %%
tran.describe()  #creating statistic report of the table as a summary (only for the numbers)
# Out:
#            amount   discount  number_of_items  risk_score  delivery_fee
# count   41.000000  41.000000        41.000000   41.000000     41.000000
# mean   422.560976   0.024740         5.512195    0.475667     10.073171
# std    263.134571   0.014324         2.739726    0.306536      6.345826
# min     17.000000   0.000596         1.000000    0.014152      0.000000
# 25%    196.000000   0.015789         3.000000    0.215655      5.000000
# 50%    387.000000   0.021974         6.000000    0.478651     10.000000
# 75%    600.000000   0.036502         7.000000    0.722797     16.000000
# max    956.000000   0.049504        10.000000    0.976911     20.000000

# %% [markdown]
# # Create Dataframe

# %%
tran[['product_id']]  #[[X2]]
# Out:
#                     product_id
# 0                      b3xjvqj
# 1                      3tkc284
# 2                      d7fhbn2
# 3   YZCTBC4JWQNE627OCIAQRPABAM
# 4                     jj6dcfdg
# 5                     hteg9fnr
# 6                      b76yq78
# 7   WJ7DHOEK4WMLFW7OXIJRGYABRY
# 8   7BNHPLRSJPBWTGTLMDJWA6HQXA
# 9                      d72d9gd
# 10  VECOP7OEMFZEZJS3NX5FLTXLM4
# 11                    mzdqay78
# 12  6VOA6SDH5LR27HCFRGU4P7T3DQ
# 13                     7k34qfw
# 14  NX4FRCEJB6HBCVQ6LYQLPQ5KWQ
# 15  AEFYC5YOLGTB4IEOAPX3YTFX4E
# 16  W2JHII6424FHXZYIIESZ2GGXBY
# 17                    8qz31w6b
# 18                     jm9dzm6
# 19                     n474brp
# 20                    9gz7qasn
# 21  AARBJEOLFMKYL4SA2WJ2DS2VS4
# 22                     8z6ph32
# 23  U5DC7KQPEZTFCYNITQMGRFKFQU
# 24  MMFZIWL7DZBUCYCYVKRLL6JIA4
# 25                     dsbjrdd
# 26                     7r95cmd
# 27                    bgaqgc8f
# 28                     67d9xsj
# ...

# %% [markdown]
# # Function

# %%
tran['number_of_items'].std()
# Out:
# 2.739725818576671

# %%
tran #get all the table
# Out:
#                           transaction_id        date  \
# 0   0029e1f5-b648-4787-b13f-563af8dbe7ff  2019-04-16
# 1   002a2614-807c-47e4-b1c4-a1198a38e058  2018-01-27
# 2   002ae1a3-2aa0-4c54-8cd5-061e2ea126e4  2019-09-28
# 3   002c1879-5910-46e8-b26b-ae1ae101d035  2018-09-12
# 4   002c40de-f032-4e10-b5bd-5ee54918cccc  2019-04-14
# 5   002d0a5c-0c06-4ba7-9e7e-750157854e9b  2019-02-06
# 6   002d71fd-f0e9-4c04-8e25-2eab403231b6  2019-02-12
# 7   002d75df-f207-4218-be5f-e97359c6d7c1  2018-06-17
# 8   002da95c-f9e2-4612-a53b-ee12b68a97bf  2019-05-27
# 9   002ebafd-08da-4002-95cd-08e98aa8e61a  2018-09-24
# 10  002fc5fc-5e5f-4fe6-8191-44155586ee64  2018-08-31
# 11  002fe359-4972-4f38-8a5f-559c079f5bac  2019-03-18
# 12  0030cddd-ec32-4ed2-949a-9d0c72150f9f  2019-05-14
# 13  0031bc5c-a945-4023-9b4c-b09dd9cbd138  2018-04-08
# 14  003208a2-880b-48ec-927e-f4ca23149543  2018-11-17
# 15  00331cf5-df7a-4fcb-a798-c224998c3799  2019-12-10
# 16  00340d42-b059-4375-b7ed-f5f7aeb117f1  2019-08-10
# ...

# %%
tran['payment_method'].value_counts()  #like group by for counting by the choosen field
# Out:
# PayPal        19
# Visa          11
# MasterCard    10
# CreditCard     1
# Name: payment_method, dtype: int64

# %%
tran['payment_method'].value_counts(normalize = True)  #in %
# Out:
# PayPal        0.463415
# Visa          0.268293
# MasterCard    0.243902
# CreditCard    0.024390
# Name: payment_method, dtype: float64

# %%
counts=tran['payment_method'].value_counts(normalize = True).to_frame()  #Insert to_frame the normalize resault to counts
counts.insert(0,'counts',tran['payment_method'].value_counts())          #Insert the simple count to the counts table (frame)
counts                                                                   #Get the table

# Normalized & agg_Sourcevalues
# Out:
#             counts  payment_method
# PayPal          19        0.463415
# Visa            11        0.268293
# MasterCard      10        0.243902
# CreditCard       1        0.024390

# %%
tran.T  #Trasnpose the table
# Out:
#                                                    0   \
# transaction_id   0029e1f5-b648-4787-b13f-563af8dbe7ff
# date                                       2019-04-16
# product_id                                    b3xjvqj
# status                                       approved
# payment_method                                 PayPal
# amount                                            152
# discount                                     0.017005
# number_of_items                                     6
# risk_score                                   0.158209
# delivery_fee                                       14
# customer_id      02cf65ec-1ef0-40a6-b44f-36e4c8b644b4
# platform                                          web
#
#                                                    1   \
# transaction_id   002a2614-807c-47e4-b1c4-a1198a38e058
# date                                       2018-01-27
# product_id                                    3tkc284
# ...

# %%
pets=pd.read_csv('lost-found-adoptable-pets.csv',usecols=['impound_no','Animal_ID','Record_Type','Current_Location','Data_Source','Animal_Gender','Animal_Breed','Animal_Color','Animal_Name'],index_col='impound_no')  #read only clolumns that i need)
pets
# Out:
#            Animal_ID                              Data_Source Record_Type  \
# impound_no
# K17-103806   A542208  Regional Animal Services of King County       FOUND
# K17-103558   A541114  Regional Animal Services of King County        LOST
# K17-104020   A543155  Regional Animal Services of King County        LOST
# K17-103994   A543033  Regional Animal Services of King County       FOUND
# K17-104418   A544774  Regional Animal Services of King County        LOST
# ...              ...                                      ...         ...
# K17-103413   A540407  Regional Animal Services of King County        LOST
# K17-104617   A545630  Regional Animal Services of King County        LOST
# K17-104272   A544172  Regional Animal Services of King County        LOST
# K17-103886   A542550  Regional Animal Services of King County        LOST
# K17-103445   A540621  Regional Animal Services of King County        LOST
#
# ...

# %% [markdown]
# # loc function

# %%
pets.loc['K17-103558']  #loc=location - find a columns and details by value
# Out:
# Animal_ID                                           A541114
# Data_Source         Regional Animal Services of King County
# Record_Type                                            LOST
# Current_Location                                       LOST
# Animal_Name                                            Neko
# Animal_Gender                                          Male
# Animal_Breed                             Domestic Shorthair
# Animal_Color                                        Unknown
# Name: K17-103558, dtype: object

# %%
pets.loc['K17-103558','Animal_Name']  #loc=location - find a specific columns and details by value #here is the name
# Out:
# 'Neko'

# %%
pets.head(2) #sample of 2 head rows
# Out:
#            Animal_ID                              Data_Source Record_Type  \
# impound_no
# K17-103806   A542208  Regional Animal Services of King County       FOUND
# K17-103558   A541114  Regional Animal Services of King County        LOST
#
#            Current_Location Animal_Name Animal_Gender        Animal_Breed  \
# impound_no
# K17-103806   In Public Home         NaN           NaN   Domestic Longhair
# K17-103558             LOST        Neko          Male  Domestic Shorthair
#
#                Animal_Color
# impound_no
# K17-103806  White / Unknown
# K17-103558          Unknown

# %%
pets.loc[['K17-103558','K17-104020','K17-103806'],['Animal_Name','Record_Type','Current_Location','Animal_Name']]
#for 3 specific value (impound_no) give me the coulumns that mentioned
# Out:
#            Animal_Name Record_Type Current_Location Animal_Name
# impound_no
# K17-103558        Neko        LOST             LOST        Neko
# K17-104020      Trixie        LOST             LOST      Trixie
# K17-103806         NaN       FOUND   In Public Home         NaN

# %%
pets.loc['K17-104020':'K17-104362']  #Range between
# Out:
#            Animal_ID                              Data_Source Record_Type  \
# impound_no
# K17-104020   A543155  Regional Animal Services of King County        LOST
# K17-103994   A543033  Regional Animal Services of King County       FOUND
# K17-104418   A544774  Regional Animal Services of King County        LOST
# K17-096407   A519032  Regional Animal Services of King County        LOST
# K17-103309   A539944  Regional Animal Services of King County        LOST
# K17-103962   A542906  Regional Animal Services of King County        LOST
# K17-104362   A544414  Regional Animal Services of King County        LOST
#
#            Current_Location Animal_Name Animal_Gender          Animal_Breed  \
# impound_no
# K17-104020             LOST      Trixie        Female  Jack Russell Terrier
# K17-103994   In Public Home         NaN        Female     Yorkshire Terrier
# K17-104418             LOST       Kitty        Female                  Manx
# ...

# %%
pets.loc['K17-104020':'K17-104362',['Animal_Name','Record_Type','Current_Location']] 
#Range between with specific columns
# Out:
#            Animal_Name Record_Type Current_Location
# impound_no
# K17-104020      Trixie        LOST             LOST
# K17-103994         NaN       FOUND   In Public Home
# K17-104418       Kitty        LOST             LOST
# K17-096407         NaN        LOST             LOST
# K17-103309     Captain        LOST             LOST
# K17-103962       Gizmo        LOST             LOST
# K17-104362         NaN        LOST             LOST

# %%
pets.iloc[:5]      #get a rows by num_rows- from first row to the number that inserted and all the columns
# Out:
#            Animal_ID                              Data_Source Record_Type  \
# impound_no
# K17-103806   A542208  Regional Animal Services of King County       FOUND
# K17-103558   A541114  Regional Animal Services of King County        LOST
# K17-104020   A543155  Regional Animal Services of King County        LOST
# K17-103994   A543033  Regional Animal Services of King County       FOUND
# K17-104418   A544774  Regional Animal Services of King County        LOST
#
#            Current_Location Animal_Name Animal_Gender          Animal_Breed  \
# impound_no
# K17-103806   In Public Home         NaN           NaN     Domestic Longhair
# K17-103558             LOST        Neko          Male    Domestic Shorthair
# K17-104020             LOST      Trixie        Female  Jack Russell Terrier
# K17-103994   In Public Home         NaN        Female     Yorkshire Terrier
# K17-104418             LOST       Kitty        Female                  Manx
#
#                Animal_Color
# ...

# %%
pets.iloc[:-1]   #get a all the rows axcept to the last row and all the columns
# Out:
#            Animal_ID                              Data_Source Record_Type  \
# impound_no
# K17-103806   A542208  Regional Animal Services of King County       FOUND
# K17-103558   A541114  Regional Animal Services of King County        LOST
# K17-104020   A543155  Regional Animal Services of King County        LOST
# K17-103994   A543033  Regional Animal Services of King County       FOUND
# K17-104418   A544774  Regional Animal Services of King County        LOST
# ...              ...                                      ...         ...
# K17-104385   A544492  Regional Animal Services of King County        LOST
# K17-103413   A540407  Regional Animal Services of King County        LOST
# K17-104617   A545630  Regional Animal Services of King County        LOST
# K17-104272   A544172  Regional Animal Services of King County        LOST
# K17-103886   A542550  Regional Animal Services of King County        LOST
#
# ...

# %%
pets.iloc[:5,:4] # 5 first rows and 4 first columns at the table
# Out:
#            Animal_ID                              Data_Source Record_Type  \
# impound_no
# K17-103806   A542208  Regional Animal Services of King County       FOUND
# K17-103558   A541114  Regional Animal Services of King County        LOST
# K17-104020   A543155  Regional Animal Services of King County        LOST
# K17-103994   A543033  Regional Animal Services of King County       FOUND
# K17-104418   A544774  Regional Animal Services of King County        LOST
#
#            Current_Location
# impound_no
# K17-103806   In Public Home
# K17-103558             LOST
# K17-104020             LOST
# K17-103994   In Public Home
# K17-104418             LOST

# %%
pets.iloc[:5].loc[:,'Data_Source':'Animal_Gender']  #involve iloc and names that not in number
# Out:
#                                         Data_Source Record_Type  \
# impound_no
# K17-103806  Regional Animal Services of King County       FOUND
# K17-103558  Regional Animal Services of King County        LOST
# K17-104020  Regional Animal Services of King County        LOST
# K17-103994  Regional Animal Services of King County       FOUND
# K17-104418  Regional Animal Services of King County        LOST
#
#            Current_Location Animal_Name Animal_Gender
# impound_no
# K17-103806   In Public Home         NaN           NaN
# K17-103558             LOST        Neko          Male
# K17-104020             LOST      Trixie        Female
# K17-103994   In Public Home         NaN        Female
# K17-104418             LOST       Kitty        Female

# %% [markdown]
# # Filtering

# %%
pets=pd.read_csv('lost-found-adoptable-pets.csv') #Reaset and read the data again
pets
# Out:
#      impound_no Animal_ID                              Data_Source  \
# 0    K17-103806   A542208  Regional Animal Services of King County
# 1    K17-103558   A541114  Regional Animal Services of King County
# 2    K17-104020   A543155  Regional Animal Services of King County
# 3    K17-103994   A543033  Regional Animal Services of King County
# 4    K17-104418   A544774  Regional Animal Services of King County
# ..          ...       ...                                      ...
# 404  K17-103413   A540407  Regional Animal Services of King County
# 405  K17-104617   A545630  Regional Animal Services of King County
# 406  K17-104272   A544172  Regional Animal Services of King County
# 407  K17-103886   A542550  Regional Animal Services of King County
# 408  K17-103445   A540621  Regional Animal Services of King County
#
#     Record_Type                                               Link  \
# 0         FOUND  http://petharbor.com/PublicDetail.asp?searchty...
# ...

# %%
pets['Animal_Name'].sort_values()     #Sort by Animal_Name
# Out:
# impound_no
# K17-104130          Ace
# K17-103964          Ace
# K17-103769        Amber
# K17-104310        Amore
# K17-102943    Anastasia
#                 ...
# K17-103442          NaN
# K17-104377          NaN
# K17-103782          NaN
# K17-103691          NaN
# K17-104294          NaN
# Name: Animal_Name, Length: 409, dtype: object

# %%
pets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   impound_no            409 non-null    object
#  1   Animal_ID             409 non-null    object
#  2   Data_Source           409 non-null    object
#  3   Record_Type           409 non-null    object
#  4   Link                  409 non-null    object
#  5   Current_Location      398 non-null    object
#  6   Animal_Name           299 non-null    object
#  7   animal_type           409 non-null    object
#  8   Age                   228 non-null    object
#  9   Animal_Gender         399 non-null    object
#  10  Animal_Breed          409 non-null    object
#  11  Animal_Color          409 non-null    object
#  12  Date                  409 non-null    object
#  13  Date_Type             409 non-null    object
#  14  Obfuscated_Address    363 non-null    object
# ...

# %%
pets['obfuscated_longitude'].sort_values(ascending=True)
# Out:
# 166   -122.330362
# 310   -122.320229
# 397   -122.315155
# 195   -122.293832
# 184   -122.290320
#           ...
# 404           NaN
# 405           NaN
# 406           NaN
# 407           NaN
# 408           NaN
# Name: obfuscated_longitude, Length: 409, dtype: float64

# %%
pets[['impound_no','Animal_ID','Animal_Name','animal_type','location_for_map']]\  #\ enter row in python
.sort_values(by=['animal_type','Animal_Name'],ascending=[True,False],inplace=True)
# Out:
#   Input In [159]
#     pets[['impound_no','Animal_ID','Animal_Name','animal_type','location_for_map']]\
#                                                                                     ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# # Filtering Values

# %%
found_pets = pets['Record_Type']=='FOUND'   #Return the table with filter of found_pets==FOUND

# %%
pets[found_pets]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [168], in <cell line: 1>()
# ----> 1 type(found_pets)
#
# NameError: name 'found_pets' is not defined

# %%
pets[pets['Record_Type']=='FOUND']  #The same like the code above
# Out:
#      impound_no Animal_ID                              Data_Source  \
# 0    K17-103806   A542208  Regional Animal Services of King County
# 3    K17-103994   A543033  Regional Animal Services of King County
# 12   K17-103457   A540735  Regional Animal Services of King County
# 20   K17-103887   A542553  Regional Animal Services of King County
# 29   K17-103377   A540353  Regional Animal Services of King County
# ..          ...       ...                                      ...
# 375  K17-103442   A540618  Regional Animal Services of King County
# 380  K17-104377   A544470  Regional Animal Services of King County
# 383  K17-103782   A542084  Regional Animal Services of King County
# 385  K17-103691   A541550  Regional Animal Services of King County
# 400  K17-104294   A544208  Regional Animal Services of King County
#
#     Record_Type                                               Link  \
# 0         FOUND  http://petharbor.com/PublicDetail.asp?searchty...
# ...

# %%
pets[pets['Record_Type']=='FOUND'][['impound_no','Animal_ID','Record_Type']]  #The same like the code above with definition of what column to get
# Out:
#      impound_no Animal_ID Record_Type
# 0    K17-103806   A542208       FOUND
# 3    K17-103994   A543033       FOUND
# 12   K17-103457   A540735       FOUND
# 20   K17-103887   A542553       FOUND
# 29   K17-103377   A540353       FOUND
# ..          ...       ...         ...
# 375  K17-103442   A540618       FOUND
# 380  K17-104377   A544470       FOUND
# 383  K17-103782   A542084       FOUND
# 385  K17-103691   A541550       FOUND
# 400  K17-104294   A544208       FOUND
#
# [200 rows x 3 columns]

# %%
big_deals=tran['amount']>500  #bigger tahn 500
tran[big_deals]
# Out:
#                           transaction_id        date  \
# 2   002ae1a3-2aa0-4c54-8cd5-061e2ea126e4  2019-09-28
# 9   002ebafd-08da-4002-95cd-08e98aa8e61a  2018-09-24
# 10  002fc5fc-5e5f-4fe6-8191-44155586ee64  2018-08-31
# 11  002fe359-4972-4f38-8a5f-559c079f5bac  2019-03-18
# 15  00331cf5-df7a-4fcb-a798-c224998c3799  2019-12-10
# 18  007369ec-e2be-46e8-90d2-3ce0df47eed0  2018-03-19
# 21  012db262-e4b9-495c-b1c7-eca37b583e57  2019-07-12
# 23  02562fb1-8c0c-47c6-a1b2-ad4d301edbfa  2018-01-11
# 25  02cf65ec-1ef0-40a6-b44f-36e4c8b644b4  2019-05-12
# 30  02f21e60-18c1-4e86-9c60-8b8cda7dcc5a  2019-06-21
# 32  02f7d55a-957a-43dd-90bf-78f7220a2d86  2018-10-30
# 35  02ffb826-75ab-4a8f-b350-478167347a4b  2019-12-20
# 36  0300a275-5844-40e1-b33d-e324b9bd23cf  2018-12-19
# 37  0300e554-af2b-4e92-8e22-cdbf1daed028  2019-11-25
# 38  03010d47-62c6-43b9-852b-d753097c8813  2019-08-16
# 39  0307b5fd-7238-4ba6-8402-d41aba331ddf  2019-01-18
#
# ...

# %%
not_mc=tran['payment_method']!='MasterCard'
tran[not_mc]
# Out:
#                           transaction_id        date  \
# 0   0029e1f5-b648-4787-b13f-563af8dbe7ff  2019-04-16
# 1   002a2614-807c-47e4-b1c4-a1198a38e058  2018-01-27
# 3   002c1879-5910-46e8-b26b-ae1ae101d035  2018-09-12
# 4   002c40de-f032-4e10-b5bd-5ee54918cccc  2019-04-14
# 5   002d0a5c-0c06-4ba7-9e7e-750157854e9b  2019-02-06
# 6   002d71fd-f0e9-4c04-8e25-2eab403231b6  2019-02-12
# 7   002d75df-f207-4218-be5f-e97359c6d7c1  2018-06-17
# 8   002da95c-f9e2-4612-a53b-ee12b68a97bf  2019-05-27
# 9   002ebafd-08da-4002-95cd-08e98aa8e61a  2018-09-24
# 10  002fc5fc-5e5f-4fe6-8191-44155586ee64  2018-08-31
# 12  0030cddd-ec32-4ed2-949a-9d0c72150f9f  2019-05-14
# 14  003208a2-880b-48ec-927e-f4ca23149543  2018-11-17
# 16  00340d42-b059-4375-b7ed-f5f7aeb117f1  2019-08-10
# 17  00356bd2-8c35-41e9-b442-8403e2dc1e22  2018-07-29
# 18  007369ec-e2be-46e8-90d2-3ce0df47eed0  2018-03-19
# 20  0115d59c-c025-4ff4-a0ee-fd2704becff4  2018-04-23
# 21  012db262-e4b9-495c-b1c7-eca37b583e57  2019-07-12
# ...

# %% [markdown]
# # Filtering Values unique

# %%
tran['payment_method'].unique()       #like distinct
# Out:
# array(['PayPal', 'Visa', 'MasterCard', 'CreditCard'], dtype=object)

# %%
tran[['payment_method','status','platform']].drop_duplicates(['payment_method','status'])
#all the distinct conjunctions for +2 columns (drop_duplicates) and get the values for the colums(paymeny_method,ststus,platform)
# Out:
#    payment_method    status platform
# 0          PayPal  approved      web
# 1            Visa  declined      web
# 2      MasterCard  approved   mobile
# 3            Visa  approved      web
# 6          PayPal  approved   mobile
# 8      CreditCard  declined   mobile
# 9            Visa  approved   mobile
# 11     MasterCard  approved      web
# 13     MasterCard  declined      web
# 22         PayPal  declined      web
# 33           Visa  declined   mobile
# 37         PayPal  declined   mobile
# 40     MasterCard  declined   mobile

# %%
tran['payment_method'].duplicated(keep='last') #keep the last time you see the distinct value
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34    False
# 35     True
# 36     True
# 37    False
# 38     True
# 39     True
# 40    False
# Name: payment_method, dtype: bool

# %%
tran[tran['date']< '2019']
# Out:
#                           transaction_id        date  \
# 1   002a2614-807c-47e4-b1c4-a1198a38e058  2018-01-27
# 3   002c1879-5910-46e8-b26b-ae1ae101d035  2018-09-12
# 7   002d75df-f207-4218-be5f-e97359c6d7c1  2018-06-17
